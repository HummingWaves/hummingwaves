# %% [markdown]
# # Whales detector

# %% [markdown]
# Here we are training the [Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection) for detecting whales

# %% [markdown]
# # Setup

# %% [markdown]
# ### Install

# %%
# For GPU
# !pip install tensorflow-gpu==1.15
# !pip install --user Cython
# !pip install --user contextlib2
# !pip install --user pillow
# !pip install --user lxml
# !pip install --user jupyter
# !pip install --user matplotlib
# !pip install --user tf_slim
# !git clone https://github.com/tensorflow/models.git
# !pip install --user pycocotools

# %%
# From tensorflow/models/research/
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
cd ../..

# %%
# From tensorflow/models/research/
# %%bash
cd models/research/
wget -O protobuf.zip https://github.com/google/protobuf/releases/download/v3.0.0/protoc-3.0.0-linux-x86_64.zip
unzip protobuf.zip
cd ../..

# %%
# From tensorflow/models/research/
# %%bash
cd models/research/
./bin/protoc object_detection/protos/*.proto --python_out=.
cd ../..

# %%
# From tensorflow/models/research/
# !cd models/research/
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ###Trainig network

# %%
# %%bash
# cd models/research/
# export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
# cd /content/drive/My\ Drive/SpaceApps/models
# python3 main_model.py \
# --logtostderr \
# --pipeline_config_path=training/ssd_mobilenet_v2_coco.config \
# --checkpoint-dir=pre-trained-model

# %% [markdown]
# ###Saving model

# %%
# %%bash
# cd models/research/
# export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
# cd /content/drive/My\ Drive/SpaceApps/models
# mkdir fine_tuned_model
# cp /content/models/research/object_detection/export_inference_graph.py .
# python3 export_inference_graph.py \
# --input_type image_tensor \
# --pipeline_config_path training/ssd_mobilenet_v2_coco.config \
# --trained_checkpoint_prefix trained/model.ckpt-240 \
# --output_directory fine_tuned_model

# %%
ls /content/models/research/object_detection/
