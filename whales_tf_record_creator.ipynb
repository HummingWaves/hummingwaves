# %% [markdown]
# # Generating tf records for learning

# %% [markdown]
# Here we are training the [Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection) for detecting whales

# %% [markdown]
# # Setup

# %% [markdown]
# ### Install

# %%
# !pip install -U --pre tensorflow=="2.*"
# !pip install --user tf_slim
# !pip install pycocotools

# %% [markdown]
# Get `tensorflow/models` or `cd` to parent directory of the repository.

# %%
import os
import pathlib


if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models

# %% [markdown]
# Compile protobufs and install the object_detection package

# %%
# %%bash
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
# %%bash
# cd models/research
# pip install .

# %% [markdown]
# ### Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import display

# %% [markdown]
# Import the object detection module.

# %%
from object_detection.utils import ops as utils_ops
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# %% [markdown]
# Patches:

# %%
# patch tf1 into `utils.ops`
utils_ops.tf = tf.compat.v1

# Patch the location of gfile
tf.gfile = tf.io.gfile

# %% [markdown]
# ###Generating tf records

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python3 '/content/drive/My Drive/SpaceApps/models/create_tfrecord.py' \
--image_dir='/content/drive/My Drive/SpaceApps/models/images/train' \
--csv_input='/content/drive/My Drive/SpaceApps/models/data/labels_train.csv' \
--output_path='/content/drive/My Drive/SpaceApps/models/train.record'

# %%
# !python3 '/content/drive/My Drive/SpaceApps/models/create_tfrecord.py' \
--image_dir='/content/drive/My Drive/SpaceApps/models/images/test' \
--csv_input='/content/drive/My Drive/SpaceApps/models/data/labels_test.csv' \
--output_path='/content/drive/My Drive/SpaceApps/models/test.record'
